# %% [markdown]
# ## Descritores

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# o problema é quando você re atribui um atributo e ele tem alguma operação dentro da classe, voce quer que a operação leve em consideração essa mudaça

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# tipo assim

# %%
class Retangulo:
    def __init__(self, l,a):
        self.l = l
        self.a = a
    
    def area(self):
        return self.a * self.l

# %%
ret = Retangulo(3,3)

# %%
ret.area
# Out:
# <bound method Retangulo.area of <__main__.Retangulo object at 0x000001CA96E68280>>

# %%
ret.area()
# Out:
# 9

# %%
ret.area = 25

# %%
ret.area
# Out:
# 25

# %% [markdown]
# masss

# %%
ret.l , ret.a
# Out:
# (3, 3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Numero:
    
    def __init__(self):
        self.n = None
        
    def get_n(self):
        return self.n
    
    def set_n(self, val):
        self.n = val
        
    def deln(self):
        del self.n

# %%
n = Numero()

# %%
n.get_n
# Out:
# <bound method Numero.get_n of <__main__.Numero object at 0x000001CA988386A0>>

# %%
n.set_n(10)

# %%
n

# %%
n.get_n()
# Out:
# 10

# %%
n.deln()

# %%
n.get_n()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 n.get_n()
#
# Cell In[10], line 7, in Numero.get_n(self)
#       6 def get_n(self):
# ----> 7     return self.n
#
# AttributeError: 'Numero' object has no attribute 'n'

# %%
class Numero:
    #mascara o n como _n
    def __init__(self):
        self.n = None
        
    def get_n(self):
        return self.n
    
    def set_n(self, val):
        self.n = val
        
    def del_n(self):
        del self.n
        
    n = property(get_n, set_n, del_n)
